# %%
# !pip install tqdm
# !pip install pandas
# !pip install py7zr
# !pip install ir_datasets
# !pip install wget
# Out:
# Collecting wget
#   Using cached wget-3.2-py3-none-any.whl
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
from transformer_rankers.datasets import downloader

#Download the data with DataDownloader
data_folder = "data"
dataDownloader = downloader.DataDownloader("mantis", data_folder)
dataDownloader.urls_to_download
#dataDownloader.download_and_preprocess()
# Out:
# ['https://docs.google.com/uc?export=download&id=17Uj9EwyGGCk9w_LIqDjlTx1y4MU7xxPv']

# %%
import pandas as pd
import numpy as np
import ast
import os
from clean import clean_and_lemmatize_string
from sklearn.metrics.pairwise import cosine_similarity
pd.set_option('display.max_colwidth', None)
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Imad Eddine
# [nltk_data]     Hajjane\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Imad Eddine
# [nltk_data]     Hajjane\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Imad Eddine
# [nltk_data]     Hajjane\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Imad Eddine
# [nltk_data]     Hajjane\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
from tensorflow.python.client import device_lib
import tensorflow as tf
tf.debugging.set_log_device_placement(True)
gpus = tf.config.list_physical_devices('GPU')
tf.config.set_visible_devices(gpus[0], 'GPU')

# %%
VOC_PATH = os.path.join("..", "result", "word_freq.csv")

# %% [markdown]
# # Load the datasets

# %%
dataframe = pd.read_csv(os.path.join("content", "clean_tweet_topics.csv"))[["text", "topics"]]
dataframe2 = pd.read_csv(os.path.join("..", "result", "Trump_tweet_opinion_analytics_with_volting.csv"))[["text", "Opinion"]]
dataframe['topics'] = dataframe['topics'].apply(lambda x: ast.literal_eval(x))

# %%
vocabulary = pd.read_csv(VOC_PATH, encoding="latin-1")["vocabulary"]

# %% [markdown]
# # Query

# %%
Q = " Donald Trump's presidential campaign"

# %%
Q_res = " ".join([word for word in clean_and_lemmatize_string(Q).split() if word in vocabulary.tolist()])
Q_res
# Out:
# 'donald trump presidential campaign'

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

vocab_size = len(vocabulary.tolist())
oov_tok = ''
embedding_dim = 300
max_length = 300
padding_type='post'
trunc_type='post'
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(dataframe["text"].tolist())

text_sequences = tokenizer.texts_to_sequences([Q_res])
text_padded = pad_sequences(text_sequences, padding='post', maxlen=max_length)

# %% [markdown]
# # Ranking

# %%
model = tf.keras.models.load_model(os.path.join("model","LSTM", "Model", "bidirectional_lstm_NN_ranking.h5"))
# Out:
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# ...

# %%
predictions = model.predict(text_padded)
# Out:
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RangeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RepeatDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RepeatDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ZipDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ParallelMapDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# ...

# %%
dataframe_res = dataframe2[['text', 'Opinion']]
dataframe_res['score'] = dataframe['topics'].apply(lambda x: cosine_similarity(predictions.reshape((1, -1)), np.array(x).reshape((1, -1))).squeeze())
dataframe_res = dataframe_res.sort_values("score", ascending=False)

# %%
dataframe_res.iloc[:15]
# Out:
#                                                                                                                                                        text
# 14174             China is primed to continue to rob us and steal our jobs through their exports http://t.co/eShZeqgZ  We need @MittRomney to rein them in.  \
# 31693            .@Morning_Joe: Marco only won the debate in the minds of desperate people. I won every on-line poll, even crazy @CNBC. Marco good looking?
# 27627                                                  """@pandoerra: @realDonaldTrump had an incredible day at Trump Bedminster. Bravo Mr. Trump"" Great."
# 36681    """@TurnberryBuzz: Today is a memorable day, the team has begun to turf our new pitch &amp, putt! http://t.co/OUxTUUKThF"" What an amazing place!"
# 28417  """@Annmajkrzak: @AP  @cbschicago I like the Trump Logo on the building! I feel this is a personal fight! &amp, will this fight cost IL residents"""
# ...
